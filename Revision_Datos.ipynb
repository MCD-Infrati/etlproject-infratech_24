# %% [markdown]
# ### Notebook para hacer una mirada rápida a las diferentes bases de datos

# %%
#Librerias a usar
import pandas as pd
import numpy as np

# %%
dftest_bsmt = pd.read_json(r'https://raw.githubusercontent.com/MCD-Infrati/etlproject-infratech_24/main/DBMongoFSF/test.bsmt.json')

# %%
dftest_bsmt
# Out:
#                                        _id        PID Bsmt Qual Bsmt Cond  \
# 0     {'$oid': '640d0ee95f254a7fe2ff616d'}  526301100        TA        Gd
# 1     {'$oid': '640d0ee95f254a7fe2ff616e'}  526350040        TA        TA
# 2     {'$oid': '640d0ee95f254a7fe2ff616f'}  526351010        TA        TA
# 3     {'$oid': '640d0ee95f254a7fe2ff6170'}  526353030        TA        TA
# 4     {'$oid': '640d0ee95f254a7fe2ff6171'}  527105010        Gd        TA
# ...                                    ...        ...       ...       ...
# 2846  {'$oid': '640d0f0d5f254a7fe2ff6cda'}  923275080        TA        TA
# 2847  {'$oid': '640d0f0d5f254a7fe2ff6cdb'}  923276100        Gd        TA
# 2848  {'$oid': '640d0f0d5f254a7fe2ff6cdc'}  923400125        Gd        TA
# 2849  {'$oid': '640d0f0d5f254a7fe2ff6cdd'}  924100070        Gd        TA
# 2850  {'$oid': '640d0f0d5f254a7fe2ff6cde'}  924151050        Gd        TA
#
#      Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  \
# ...

# %% [markdown]
# Cambio de algo
