# %% [markdown]
# ### Notebook para hacer una mirada rápida a las diferentes bases de datos

# %%
#Librerias a usar
import pandas as pd
import numpy as np

# %%
#Carga conujntos de datos inciales
dftest_bsmt = pd.read_csv(r'https://raw.githubusercontent.com/MCD-Infrati/etlproject-infratech_24/main/DBMongoFSF/test.bsmt.csv')

# %%
#visualización para análisis con datawrangler
dftest_bsmt
# Out:
#                            _id        PID Bsmt Qual Bsmt Cond Bsmt Exposure  \
# 0     640d0ee95f254a7fe2ff616d  526301100        TA        Gd            Gd
# 1     640d0ee95f254a7fe2ff616e  526350040        TA        TA            No
# 2     640d0ee95f254a7fe2ff616f  526351010        TA        TA            No
# 3     640d0ee95f254a7fe2ff6170  526353030        TA        TA            No
# 4     640d0ee95f254a7fe2ff6171  527105010        Gd        TA            No
# ...                        ...        ...       ...       ...           ...
# 2846  640d0f0d5f254a7fe2ff6cda  923275080        TA        TA            Av
# 2847  640d0f0d5f254a7fe2ff6cdb  923276100        Gd        TA            Av
# 2848  640d0f0d5f254a7fe2ff6cdc  923400125        Gd        TA            Av
# 2849  640d0f0d5f254a7fe2ff6cdd  924100070        Gd        TA            Av
# 2850  640d0f0d5f254a7fe2ff6cde  924151050        Gd        TA            Av
#
# ...

# %%
dftest_bsmt.isnull().count()
# Out:
# _id               2851
# PID               2851
# Bsmt Qual         2851
# Bsmt Cond         2851
# Bsmt Exposure     2851
# BsmtFin Type 1    2851
# BsmtFin SF 1      2851
# BsmtFin Type 2    2851
# BsmtFin SF 2      2851
# Bsmt Unf SF       2851
# Total Bsmt SF     2851
# Bsmt Full Bath    2851
# Bsmt Half Bath    2851
# dtype: int64
